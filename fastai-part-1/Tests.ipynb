# %%
from fastai.vision import *
import os

# %%
import numpy as np

# %%
path = Path('/storage/bedroom/1/a/a/1aaaee800d5aa223ac43f5f07d3994ade4a6afaa.jpg')

# %%
img = open_image(path)

# %%
type(img)
# Out:
# fastai.vision.image.Image

# %%
img.show()

# %%
t = img.data

# %%
t
# Out:
# tensor([[[0.7608, 0.7608, 0.7608,  ..., 0.7765, 0.7765, 0.7765],
#          [0.7608, 0.7608, 0.7608,  ..., 0.7765, 0.7765, 0.7765],
#          [0.7608, 0.7608, 0.7608,  ..., 0.7765, 0.7765, 0.7765],
#          ...,
#          [0.9098, 0.9098, 0.9098,  ..., 0.8784, 0.8784, 0.8784],
#          [0.9137, 0.9137, 0.9137,  ..., 0.8784, 0.8784, 0.8784],
#          [0.9137, 0.9137, 0.9137,  ..., 0.8784, 0.8784, 0.8784]],
#
#         [[0.7529, 0.7529, 0.7529,  ..., 0.7765, 0.7765, 0.7765],
#          [0.7529, 0.7529, 0.7529,  ..., 0.7765, 0.7765, 0.7765],
#          [0.7529, 0.7529, 0.7529,  ..., 0.7765, 0.7765, 0.7765],
#          ...,
#          [0.9255, 0.9255, 0.9255,  ..., 0.8902, 0.8902, 0.8902],
#          [0.9294, 0.9294, 0.9294,  ..., 0.8902, 0.8902, 0.8902],
#          [0.9294, 0.9294, 0.9294,  ..., 0.8902, 0.8902, 0.8902]],
#
#         [[0.7647, 0.7647, 0.7647,  ..., 0.8235, 0.8235, 0.8235],
#          [0.7647, 0.7647, 0.7647,  ..., 0.8235, 0.8235, 0.8235],
# ...

# %%
a = t.numpy()

# %%
type(a)
# Out:
# numpy.ndarray

# %%
img2 = Image(torch.from_numpy(a))

# %%
type(tt)
# Out:
# torch.Tensor

# %%
img2 = Image(tt)

# %%
img2.show()

# %%
img2.save()
